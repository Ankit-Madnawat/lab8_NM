# %%
pip install ncclient
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ncclient in ./.local/lib/python3.6/site-packages (0.6.9)
# Requirement already satisfied: setuptools>0.6 in ./.local/lib/python3.6/site-packages (from ncclient) (50.3.2)
# Requirement already satisfied: lxml>=3.3.0 in ./.local/lib/python3.6/site-packages (from ncclient) (4.6.1)
# Requirement already satisfied: paramiko>=1.15.0 in ./.local/lib/python3.6/site-packages (from ncclient) (2.7.2)
# Requirement already satisfied: six in ./.local/lib/python3.6/site-packages (from ncclient) (1.15.0)
# Requirement already satisfied: cryptography>=2.5 in ./.local/lib/python3.6/site-packages (from paramiko>=1.15.0->ncclient) (3.2.1)
# Requirement already satisfied: bcrypt>=3.1.3 in ./.local/lib/python3.6/site-packages (from paramiko>=1.15.0->ncclient) (3.2.0)
# Requirement already satisfied: pynacl>=1.0.1 in ./.local/lib/python3.6/site-packages (from paramiko>=1.15.0->ncclient) (1.4.0)
# Requirement already satisfied: cffi>=1.1 in ./.local/lib/python3.6/site-packages (from bcrypt>=3.1.3->paramiko>=1.15.0->ncclient) (1.14.3)
# Requirement already satisfied: six in ./.local/lib/python3.6/site-packages (from ncclient) (1.15.0)
# Requirement already satisfied: pycparser in ./.local/lib/python3.6/site-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko>=1.15.0->ncclient) (2.20)
# Requirement already satisfied: cffi>=1.1 in ./.local/lib/python3.6/site-packages (from bcrypt>=3.1.3->paramiko>=1.15.0->ncclient) (1.14.3)
# Requirement already satisfied: six in ./.local/lib/python3.6/site-packages (from ncclient) (1.15.0)
# Requirement already satisfied: cffi>=1.1 in ./.local/lib/python3.6/site-packages (from bcrypt>=3.1.3->paramiko>=1.15.0->ncclient) (1.14.3)
# Requirement already satisfied: six in ./.local/lib/python3.6/site-packages (from ncclient) (1.15.0)
# WARNING: You are using pip version 20.3.1; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from ncclient import manager

m = manager.connect(host='198.51.100.1', port=22, username='ankit', password='lab8', hostkey_verify=False, device_params={'name':'csr'})
c = m.get_config(source='running')
print(c)
#with open("%s.xml" % host, 'w') as f:
#    f.write(c)
# Out:
# ---------------------------------------------------------------------------
# TimeoutExpiredError                       Traceback (most recent call last)
# <ipython-input-20-ba17d4b98ce8> in <module>
#       2
#       3 m = manager.connect(host='198.51.100.1', port=22, username='ankit', password='lab8', hostkey_verify=False, device_params={'name':'csr'}, timeout=300)
# ----> 4 c = m.get_config(source='running')
#       5 print(c)
#       6 #with open("%s.xml" % host, 'w') as f:
#
# ~/.local/lib/python3.6/site-packages/ncclient/manager.py in execute(self, cls, *args, **kwds)
#     229                    timeout=self._timeout,
#     230                    raise_mode=self._raise_mode,
# --> 231                    huge_tree=self._huge_tree).request(*args, **kwds)
#     232
#     233     def locked(self, target):
#
# ~/.local/lib/python3.6/site-packages/ncclient/operations/retrieve.py in request(self, source, filter, with_defaults)
#     164                 self._session.server_capabilities,
#     165             )
# --> 166         return self._request(node)
#     167
#     168 class GetSchema(RPC):
#
# ~/.local/lib/python3.6/site-packages/ncclient/operations/rpc.py in _request(self, op)
#     364                     return self._reply
#     365             else:
# --> 366                 raise TimeoutExpiredError('ncclient timed out while waiting for an rpc reply.')
#     367
#     368     def request(self):
#
# TimeoutExpiredError: ncclient timed out while waiting for an rpc reply.

# %%
from ncclient import manager
import xmltodict
# Create filter template for an interface
interface_filter = """
<filter>
<interfaces xmlns="urn:ietf:params:xml:ns:yang:ietf-interfaces">
<interface>
<name>{int_name}</name>
</interface>
</interfaces>
</filter>
"""
# Open NETCONF connection to device
with manager.connect(host='198.51.100.1', port=22, username='ankit', password='lab8', hostkey_verify=False) as m:
    # Create desired NETCONF filter and <get-config>
    filter = interface_filter.format(int_name = "FastEthernet0/0")
    r = m.get_config("running", filter)
    # Process the XML data into Python Dictionary and use
    interface = xmltodict.parse(r.xml)
    interface = interface["rpc-reply"]["data"]["interfaces"]["interface"]
    print("The interface {name} has ip address {ip}/{mask}".format(
    name = interface["name"]["#text"],
    ip = interface["ipv4"]["address"]["ip"],
    mask = interface["ipv4"]["address"]["netmask"],
    )
    )
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-21-3fc9ad1fd690> in <module>
#       1 from ncclient import manager
# ----> 2 import xmltodict
#       3 # Create filter template for an interface
#       4 interface_filter = """
#       5 <filter>
#
# ModuleNotFoundError: No module named 'xmltodict'

# %%
pip install xmltodict
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting xmltodict
#   Downloading xmltodict-0.12.0-py2.py3-none-any.whl (9.2 kB)
# Installing collected packages: xmltodict
# Successfully installed xmltodict-0.12.0
# WARNING: You are using pip version 20.3.1; however, version 21.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from ncclient import manager
import xmltodict
# Create filter template for an interface
interface_filter = """
<filter>
<interfaces xmlns="urn:ietf:params:xml:ns:yang:ietf-interfaces">
<interface>
<name>{int_name}</name>
</interface>
</interfaces>
</filter>
"""
# Open NETCONF connection to device
with manager.connect(host='198.51.100.1', port=22, username='ankit', password='lab8', hostkey_verify=False) as m:
    # Create desired NETCONF filter and <get-config>
    filter = interface_filter.format(int_name = "FastEthernet0/0")
    r = m.get_config("running", filter)
    # Process the XML data into Python Dictionary and use
    interface = xmltodict.parse(r.xml)
    interface = interface["rpc-reply"]["data"]["interfaces"]["interface"]
    print("The interface {name} has ip address {ip}/{mask}".format(
    name = interface["name"]["#text"],
    ip = interface["ipv4"]["address"]["ip"],
    mask = interface["ipv4"]["address"]["netmask"],
    )
    )
    m.close_session()
# Out:
# ---------------------------------------------------------------------------
# TimeoutExpiredError                       Traceback (most recent call last)
# <ipython-input-2-cc4a2c9ff80a> in <module>
#      16     filter = interface_filter.format(int_name = "FastEthernet0/0")
# ---> 17     r = m.get_config("running", filter)
#      18     # Process the XML data into Python Dictionary and use
#
# ~/.local/lib/python3.6/site-packages/ncclient/manager.py in execute(self, cls, *args, **kwds)
#     230                    raise_mode=self._raise_mode,
# --> 231                    huge_tree=self._huge_tree).request(*args, **kwds)
#     232
#
# ~/.local/lib/python3.6/site-packages/ncclient/operations/retrieve.py in request(self, source, filter, with_defaults)
#     165             )
# --> 166         return self._request(node)
#     167
#
# ~/.local/lib/python3.6/site-packages/ncclient/operations/rpc.py in _request(self, op)
#     365             else:
# --> 366                 raise TimeoutExpiredError('ncclient timed out while waiting for an rpc reply.')
#     367
#
# TimeoutExpiredError: ncclient timed out while waiting for an rpc reply.
#
# During handling of the above exception, another exception occurred:
#
# TimeoutExpiredError                       Traceback (most recent call last)
# <ipython-input-2-cc4a2c9ff80a> in <module>
#      25     )
#      26     )
# ---> 27     m.close_session()
#
# ~/.local/lib/python3.6/site-packages/ncclient/manager.py in __exit__(self, *args)
#     210
#     211     def __exit__(self, *args):
# --> 212         self.close_session()
#     213         return False
#     214
#
# ~/.local/lib/python3.6/site-packages/ncclient/manager.py in execute(self, cls, *args, **kwds)
#     229                    timeout=self._timeout,
#     230                    raise_mode=self._raise_mode,
# --> 231                    huge_tree=self._huge_tree).request(*args, **kwds)
#     232
#     233     def locked(self, target):
#
# ~/.local/lib/python3.6/site-packages/ncclient/operations/session.py in request(self)
#      26         "Request graceful termination of the NETCONF session, and also close the transport."
#      27         try:
# ---> 28             return self._request(new_ele("close-session"))
#      29         finally:
#      30             self.session.close()
#
# ~/.local/lib/python3.6/site-packages/ncclient/operations/rpc.py in _request(self, op)
#     364                     return self._reply
#     365             else:
# --> 366                 raise TimeoutExpiredError('ncclient timed out while waiting for an rpc reply.')
#     367
#     368     def request(self):
#
# TimeoutExpiredError: ncclient timed out while waiting for an rpc reply.

# %%
from ncclient import manager

m = manager.connect(host='198.51.100.1', port=22, username='ankit', password='lab8', hostkey_verify=False, device_params={'name':'csr'})
for i in m.server_capabilities:
    print(i)
# Out:
# urn:ietf:params:netconf:base:1.0
# urn:ietf:params:netconf:capability:writeable-running:1.0
# urn:ietf:params:netconf:capability:startup:1.0
# urn:ietf:params:netconf:capability:url:1.0
# urn:cisco:params:netconf:capability:pi-data-model:1.0
# urn:cisco:params:netconf:capability:notification:1.0

# %%
from ncclient import manager

m = manager.connect(host='198.51.100.1', port=22, username='ankit', password='lab8', hostkey_verify=False, allow_agent=False, look_for_keys=True, device_params={'name':'iosxr'})
c = m.get_config(source='running').xml
print(c)
m.close_session()
# Out:
# <?xml version="1.0" encoding="UTF-8"?><rpc-reply message-id="urn:uuid:2bb00b03-fc9a-4004-8e66-52672586d2ed" xmlns="urn:ietf:params:netconf:base:1.0"><data><cli-config-data-block>!
# ! Last configuration change at 17:28:04 UTC Mon Nov 1 2021
# !
# version 15.2
# service timestamps debug datetime msec
# service timestamps log datetime msec
# !
# hostname Lab8Router
# !
# boot-start-marker
# boot-end-marker
# !
# !
# !
# no aaa new-model
# no ip icmp rate-limit unreachable
# ip cef
# !
# !
# !
# !
# !
# !
# no ip domain lookup
# ip domain name ankit_lab8
# no ipv6 cef
# !
# !
# multilink bundle-name authenticated
# !
# !
# !
# !
# !
# !
# !
# username ankit privilege 15 password 0 lab8
# !
# !
# ip tcp synwait-time 5
# ip ssh version 2
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# interface Loopback10
#  ip address 10.1.1.1 255.255.255.255
# !
# interface FastEthernet0/0
#  ip address 198.51.100.1 255.255.255.0
#  duplex full
# !
# interface FastEthernet1/0
#  no ip address
#  shutdown
#  speed auto
#  duplex auto
# !
# interface FastEthernet1/1
#  no ip address
#  shutdown
#  speed auto
#  duplex auto
# !
# interface FastEthernet2/0
#  no ip address
#  shutdown
#  speed auto
#  duplex auto
# !
# interface FastEthernet2/1
#  no ip address
#  shutdown
#  speed auto
#  duplex auto
# !
# interface GigabitEthernet3/0
#  no ip address
#  shutdown
#  negotiation auto
# !
# ip forward-protocol nd
# !
# !
# no ip http server
# no ip http secure-server
# !
# !
# !
# !
# control-plane
# !
# !
# line con 0
#  exec-timeout 0 0
# line aux 0
#  exec-timeout 0 0
# line vty 0 4
#  exec-timeout 0 0
#  login local
#  transport input ssh
# line vty 5 15
#  exec-timeout 0 0
#  login local
#  transport input ssh
# !
# netconf max-sessions 16
# netconf ssh
# !
# </cli-config-data-block></data></rpc-reply>
# <?xml version="1.0" encoding="UTF-8"?><rpc-reply message-id="urn:uuid:e52b4811-e6a2-43ac-9cc2-d17778f4d0c0" xmlns="urn:ietf:params:netconf:base:1.0"><ok /></rpc-reply>

# %%
import csv

with open("lab8-obj2-conf.csv","r") as f:
    reader = csv.DictReader(f)
    for row in reader:
        if row:
            print(row["RouterIP"],row["Hostname"],row["Loopback99IP"],row["LoopbackSubnet"],row["OSPFarea"],row["OSPFNetwork"],row["WildMask"])
# Out:
# 198.51.100.11 Router1 10.1.1.1 255.255.255.0 0 10.1.1.0 0.0.0.255
# 198.51.100.12 Router2 10.1.2.1 255.255.255.0 0 10.1.2.0 0.0.0.255
# 198.51.100.13 Router3 10.1.3.1 255.255.255.0 0 10.1.3.0 0.0.0.255
# 198.51.100.14 Router4 10.1.4.1 255.255.255.0 0 10.1.4.0 0.0.0.255
# 198.51.100.15 Router5 10.1.5.1 255.255.255.0 0 10.1.5.0 0.0.0.255

# %%
import csv

hosts=[]
hostname=[]
loopbackIP=[]
loopbackSubnet=[]
OSPFarea=[]
OSPFnetwork=[]
Wildmask=[]
with open("lab8-obj2-conf.csv","r") as file:
    reader = csv.DictReader(file)
    for row in reader:
        if row:
            hosts.append(row["RouterIP"])
            hostname.append(row["Hostname"])
            loopbackIP.append(row["Loopback99IP"])
            loopbackSubnet.append(row["LoopbackSubnet"])
            OSPFarea.append(row["OSPFarea"])
            OSPFnetwork.append(row["OSPFNetwork"])
            Wildmask.append(row["WildMask"])
print(hosts)
print(hostname)
print(loopbackIP)
print(loopbackSubnet)
print(OSPFarea)
print(OSPFnetwork)
print(Wildmask)
# Out:
# ['198.51.100.11', '198.51.100.12', '198.51.100.13', '198.51.100.14', '198.51.100.15']
# ['Router1', 'Router2', 'Router3', 'Router4', 'Router5']
# ['10.1.1.1', '10.1.2.1', '10.1.3.1', '10.1.4.1', '10.1.5.1']
# ['255.255.255.0', '255.255.255.0', '255.255.255.0', '255.255.255.0', '255.255.255.0']
# ['0', '0', '0', '0', '0']
# ['10.1.1.0', '10.1.2.0', '10.1.3.0', '10.1.4.0', '10.1.5.0']
# ['0.0.0.255', '0.0.0.255', '0.0.0.255', '0.0.0.255', '0.0.0.255']

# %%
from ncclient import manager

xml_filter = """ 
    <native xmlns="http://cisco.com/ns/yang/Cisco-IOS-XE-native"> 
    </native> 
"""

m = manager.connect(host='198.51.100.11', port=22, username='lab', password='lab123', hostkey_verify=False)
c = m.get(('subtree', xml_filter))
print(c)
m.close_session()
# Out:
# ---------------------------------------------------------------------------
# TimeoutExpiredError                       Traceback (most recent call last)
# <ipython-input-6-5c467d926f64> in <module>
#       7
#       8 m = manager.connect(host='198.51.100.11', port=22, username='lab', password='lab123', hostkey_verify=False)
# ----> 9 c = m.get(('subtree', xml_filter))
#      10 print(c)
#      11 m.close_session()
#
# ~/.local/lib/python3.6/site-packages/ncclient/manager.py in execute(self, cls, *args, **kwds)
#     229                    timeout=self._timeout,
#     230                    raise_mode=self._raise_mode,
# --> 231                    huge_tree=self._huge_tree).request(*args, **kwds)
#     232
#     233     def locked(self, target):
#
# ~/.local/lib/python3.6/site-packages/ncclient/operations/retrieve.py in request(self, filter, with_defaults)
#      89                 self._session.server_capabilities,
#      90             )
# ---> 91         return self._request(node)
#      92
#      93
#
# ~/.local/lib/python3.6/site-packages/ncclient/operations/rpc.py in _request(self, op)
#     364                     return self._reply
#     365             else:
# --> 366                 raise TimeoutExpiredError('ncclient timed out while waiting for an rpc reply.')
#     367
#     368     def request(self):
#
# TimeoutExpiredError: ncclient timed out while waiting for an rpc reply.

# %%
from ncclient import manager

m = manager.connect(host='198.51.100.11', port=22, username='lab', password='lab123', hostkey_verify=False)

print(m.connected)
# Out:
# True

# %%
from ncclient import manager

m = manager.connect(host='198.51.100.11', port=22, username='lab', password='lab123', hostkey_verify=False)

for c in m.server_capabilities:
    print(c)
# Out:
# urn:ietf:params:netconf:base:1.0
# urn:ietf:params:netconf:capability:writeable-running:1.0
# urn:ietf:params:netconf:capability:startup:1.0
# urn:ietf:params:netconf:capability:url:1.0
# urn:cisco:params:netconf:capability:pi-data-model:1.0
# urn:cisco:params:netconf:capability:notification:1.0

# %%
from ncclient import manager
import xmltodict
import xml.dom.minidom

m = manager.connect(host='198.51.100.11', port=22, username='lab', password='lab123', hostkey_verify=False)
running_config = m.get_config('running')
print(xml.dom.minidom.parseString(str(running_config)).toprettyxml())
# Out:
# ---------------------------------------------------------------------------
# TimeoutExpiredError                       Traceback (most recent call last)
# <ipython-input-10-76c3d3364cad> in <module>
#       4
#       5 m = manager.connect(host='198.51.100.11', port=22, username='lab', password='lab123', hostkey_verify=False)
# ----> 6 running_config = m.get_config('running')
#       7 print(xml.dom.minidom.parseString(str(running_config)).toprettyxml())
#
# ~/.local/lib/python3.6/site-packages/ncclient/manager.py in execute(self, cls, *args, **kwds)
#     229                    timeout=self._timeout,
#     230                    raise_mode=self._raise_mode,
# --> 231                    huge_tree=self._huge_tree).request(*args, **kwds)
#     232
#     233     def locked(self, target):
#
# ~/.local/lib/python3.6/site-packages/ncclient/operations/retrieve.py in request(self, source, filter, with_defaults)
#     164                 self._session.server_capabilities,
#     165             )
# --> 166         return self._request(node)
#     167
#     168 class GetSchema(RPC):
#
# ~/.local/lib/python3.6/site-packages/ncclient/operations/rpc.py in _request(self, op)
#     364                     return self._reply
#     365             else:
# --> 366                 raise TimeoutExpiredError('ncclient timed out while waiting for an rpc reply.')
#     367
#     368     def request(self):
#
# TimeoutExpiredError: ncclient timed out while waiting for an rpc reply.

# %%
import csv
from ncclient import manager

hosts=[]
hostname=[]
loopbackIP=[]
loopbackSubnet=[]
OSPFarea=[]
OSPFnetwork=[]
Wildmask=[]
with open("lab8-obj2-conf.csv","r") as file:
    reader = csv.DictReader(file)
    for row in reader:
        if row:
            hosts.append(row["RouterIP"])
            hostname.append(row["Hostname"])
            loopbackIP.append(row["Loopback99IP"])
            loopbackSubnet.append(row["LoopbackSubnet"])
            OSPFarea.append(row["OSPFarea"])
            OSPFnetwork.append(row["OSPFNetwork"])
            Wildmask.append(row["WildMask"])


for i in range(0,len(hosts)):
    
    CONFIG_COMMANDS = """
        <config>
            <cli-config-data>
                <cmd>hostname hostname[i]</cmd>
                <cmd>interface Loopback99</cmd>
                <cmd>ip address loopbackIP[i] loopbackSubnet[i]</cmd>
                <cmd>router ospf 1</cmd>
                <cmd>network OSPFnetwork[i] Wildmask[i] area OSPFarea[i]</cmd>
            </cli-config-data>
        </config>
     """
    
    m = manager.connect(host=hosts[i], port=22, username='lab', password='lab123', hostkey_verify=False)
    output = m.edit_config(CONFIG_COMMANDS, target='running')
    print(output)
    m.close_session()
# Out:
# ---------------------------------------------------------------------------
# TimeoutExpiredError                       Traceback (most recent call last)
# <ipython-input-5-7bc04d32aeca> in <module>
#      37
#      38     m = manager.connect(host=hosts[i], port=22, username='lab', password='lab123', hostkey_verify=False)
# ---> 39     output = m.edit_config(CONFIG_COMMANDS, target='running')
#      40     print(output)
#      41     m.close_session()
#
# ~/.local/lib/python3.6/site-packages/ncclient/manager.py in execute(self, cls, *args, **kwds)
#     229                    timeout=self._timeout,
#     230                    raise_mode=self._raise_mode,
# --> 231                    huge_tree=self._huge_tree).request(*args, **kwds)
#     232
#     233     def locked(self, target):
#
# ~/.local/lib/python3.6/site-packages/ncclient/operations/edit.py in request(self, config, format, target, default_operation, test_option, error_option)
#      67             config_text = sub_ele(node, "config-text")
#      68             sub_ele(config_text, "configuration-text").text = config
# ---> 69         return self._request(node)
#      70
#      71
#
# ~/.local/lib/python3.6/site-packages/ncclient/operations/rpc.py in _request(self, op)
#     364                     return self._reply
#     365             else:
# --> 366                 raise TimeoutExpiredError('ncclient timed out while waiting for an rpc reply.')
#     367
#     368     def request(self):
#
# TimeoutExpiredError: ncclient timed out while waiting for an rpc reply.

# %%
import csv
from ncclient import manager

hosts=[]
hostnames=[]
loopbackIPs=[]
loopbackSubnets=[]
OSPFareas=[]
OSPFnetworks=[]
Wildmasks=[]
with open("lab8-obj2-conf.csv","r") as file:
    reader = csv.DictReader(file)
    for row in reader:
        if row:
            hosts.append(row["RouterIP"])
            hostnames.append(row["Hostname"])
            loopbackIPs.append(row["Loopback99IP"])
            loopbackSubnets.append(row["LoopbackSubnet"])
            OSPFareas.append(row["OSPFarea"])
            OSPFnetworks.append(row["OSPFNetwork"])
            Wildmasks.append(row["WildMask"])


CONFIG_COMMANDS = """
    <config>
        <cli-config-data>
            <cmd>hostname %s</cmd>
            <cmd>interface Loopback99</cmd>
            <cmd>ip address %s %s</cmd>
            <cmd>router ospf 1</cmd>
            <cmd>network %s %s area %s</cmd>
        </cli-config-data>
    </config>
"""
    

def update_config(conn, hostname, loopbackip, loopbacksubnet, OSPFnetwork, Wildmask, area):
    config_str = CONFIG_COMMANDS % (hostname, loopbackip, loopbacksubnet, OSPFnetwork, Wildmask, area)
    conn.edit_config(target='running', config=config_str)

for (host, hostname, loopbackip, loopbacksubnet, OSPFnetwork, Wildmask, area) in zip(hosts, hostnames, loopbackIPs, loopbackSubnets, OSPFnetworks, Wildmasks, OSPFareas):
    conn = manager.connect(host=host, port=22, username='lab', password='lab123', hostkey_verify=False, allow_agent=False, look_for_keys=True, device_params={'name':'iosxr'})
    update_config(conn, hostname, loopbackip, loopbacksubnet, OSPFnetwork, Wildmask, area)
# Out:
# ---------------------------------------------------------------------------
# TimeoutExpiredError                       Traceback (most recent call last)
# <ipython-input-1-7a7333579121> in <module>
#      41 for (host, hostname, loopbackip, loopbacksubnet, OSPFnetwork, Wildmask, area) in zip(hosts, hostnames, loopbackIPs, loopbackSubnets, OSPFnetworks, Wildmasks, OSPFareas):
#      42     conn = manager.connect(host=host, port=22, username='lab', password='lab123', hostkey_verify=False, allow_agent=False, look_for_keys=True, device_params={'name':'csr'})
# ---> 43     update_config(conn, hostname, loopbackip, loopbacksubnet, OSPFnetwork, Wildmask, area)
#      44
#
# <ipython-input-1-7a7333579121> in update_config(conn, hostname, loopbackip, loopbacksubnet, OSPFnetwork, Wildmask, area)
#      37 def update_config(conn, hostname, loopbackip, loopbacksubnet, OSPFnetwork, Wildmask, area):
#      38     config_str = CONFIG_COMMANDS % (hostname, loopbackip, loopbacksubnet, OSPFnetwork, Wildmask, area)
# ---> 39     conn.edit_config(target='running', config=config_str)
#      40
#      41 for (host, hostname, loopbackip, loopbacksubnet, OSPFnetwork, Wildmask, area) in zip(hosts, hostnames, loopbackIPs, loopbackSubnets, OSPFnetworks, Wildmasks, OSPFareas):
#
# ~/.local/lib/python3.6/site-packages/ncclient/manager.py in execute(self, cls, *args, **kwds)
#     229                    timeout=self._timeout,
#     230                    raise_mode=self._raise_mode,
# --> 231                    huge_tree=self._huge_tree).request(*args, **kwds)
#     232
#     233     def locked(self, target):
#
# ~/.local/lib/python3.6/site-packages/ncclient/operations/edit.py in request(self, config, format, target, default_operation, test_option, error_option)
#      67             config_text = sub_ele(node, "config-text")
#      68             sub_ele(config_text, "configuration-text").text = config
# ---> 69         return self._request(node)
#      70
#      71
#
# ~/.local/lib/python3.6/site-packages/ncclient/operations/rpc.py in _request(self, op)
#     364                     return self._reply
#     365             else:
# --> 366                 raise TimeoutExpiredError('ncclient timed out while waiting for an rpc reply.')
#     367
#     368     def request(self):
#
# TimeoutExpiredError: ncclient timed out while waiting for an rpc reply.

# %%
from ncclient import manager

m = manager.connect(host='198.51.100.1', port=22, username='ankit', password='lab8', hostkey_verify=False, allow_agent=False, look_for_keys=True, device_params={'name':'iosxr'})
c = m.get_config(source='running')
print(c)
m.close_session()
# Out:
# <?xml version="1.0" encoding="UTF-8"?><rpc-reply message-id="urn:uuid:93ba81a5-7973-49c5-8ecc-1682c35c640f" xmlns="urn:ietf:params:netconf:base:1.0"><data><cli-config-data-block>!
# version 15.2
# service timestamps debug datetime msec
# service timestamps log datetime msec
# !
# hostname Lab8Router
# !
# boot-start-marker
# boot-end-marker
# !
# !
# !
# no aaa new-model
# no ip icmp rate-limit unreachable
# ip cef
# !
# !
# !
# !
# !
# !
# no ip domain lookup
# ip domain name ankit_lab8
# no ipv6 cef
# !
# !
# multilink bundle-name authenticated
# !
# !
# !
# !
# !
# !
# !
# username ankit privilege 15 password 0 lab8
# !
# !
# ip tcp synwait-time 5
# ip ssh version 2
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# interface Loopback10
#  ip address 10.1.1.1 255.255.255.255
# !
# interface FastEthernet0/0
#  ip address 198.51.100.1 255.255.255.0
#  duplex full
# !
# interface FastEthernet1/0
#  no ip address
#  shutdown
#  speed auto
#  duplex auto
# !
# interface FastEthernet1/1
#  no ip address
#  shutdown
#  speed auto
#  duplex auto
# !
# interface FastEthernet2/0
#  no ip address
#  shutdown
#  speed auto
#  duplex auto
# !
# interface FastEthernet2/1
#  no ip address
#  shutdown
#  speed auto
#  duplex auto
# !
# interface GigabitEthernet3/0
#  no ip address
#  shutdown
#  negotiation auto
# !
# ip forward-protocol nd
# !
# !
# no ip http server
# no ip http secure-server
# !
# !
# !
# !
# control-plane
# !
# !
# line con 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line aux 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line vty 0 4
#  login local
#  transport input ssh
# line vty 5 15
#  login local
#  transport input ssh
# !
# netconf ssh
# !
# </cli-config-data-block></data></rpc-reply>
# <?xml version="1.0" encoding="UTF-8"?><rpc-reply message-id="urn:uuid:d0f0bfd4-f039-456a-8dbb-517a97db8e73" xmlns="urn:ietf:params:netconf:base:1.0"><ok /></rpc-reply>

# %%
from ncclient import manager

m = manager.connect(host='198.51.100.1', port=22, username='ankit', password='lab8', hostkey_verify=False, allow_agent=False, look_for_keys=True, device_params={'name':'iosxr'})
c = m.get_config(source='running')
print(c)
m.close_session()
print(type(c))
# Out:
# <?xml version="1.0" encoding="UTF-8"?><rpc-reply message-id="urn:uuid:a9faa66c-9156-414c-978c-f6586f539c85" xmlns="urn:ietf:params:netconf:base:1.0"><data><cli-config-data-block>!
# version 15.2
# service timestamps debug datetime msec
# service timestamps log datetime msec
# !
# hostname Lab8Router
# !
# boot-start-marker
# boot-end-marker
# !
# !
# !
# no aaa new-model
# no ip icmp rate-limit unreachable
# ip cef
# !
# !
# !
# !
# !
# !
# no ip domain lookup
# ip domain name ankit_lab8
# no ipv6 cef
# !
# !
# multilink bundle-name authenticated
# !
# !
# !
# !
# !
# !
# !
# username ankit privilege 15 password 0 lab8
# !
# !
# ip tcp synwait-time 5
# ip ssh version 2
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# interface Loopback10
#  ip address 10.1.1.1 255.255.255.255
# !
# interface FastEthernet0/0
#  ip address 198.51.100.1 255.255.255.0
#  duplex full
# !
# interface FastEthernet1/0
#  no ip address
#  shutdown
#  speed auto
#  duplex auto
# !
# interface FastEthernet1/1
#  no ip address
#  shutdown
#  speed auto
#  duplex auto
# !
# interface FastEthernet2/0
#  no ip address
#  shutdown
#  speed auto
#  duplex auto
# !
# interface FastEthernet2/1
#  no ip address
#  shutdown
#  speed auto
#  duplex auto
# !
# interface GigabitEthernet3/0
#  no ip address
#  shutdown
#  negotiation auto
# !
# ip forward-protocol nd
# !
# !
# no ip http server
# no ip http secure-server
# !
# !
# !
# !
# control-plane
# !
# !
# line con 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line aux 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line vty 0 4
#  login local
#  transport input ssh
# line vty 5 15
#  login local
#  transport input ssh
# !
# netconf ssh
# !
# </cli-config-data-block></data></rpc-reply>
# <class 'ncclient.operations.retrieve.GetReply'>

# %%
from ncclient import manager

m = manager.connect(host='198.51.100.1', port=22, username='ankit', password='lab8', hostkey_verify=False, allow_agent=False, look_for_keys=True, device_params={'name':'iosxr'})
c = m.get_config(source='running')
print(c)
m.close_session()
print(f'Interface name: { cli-config-data-block["name"]["#text"] }')
# Out:
# <?xml version="1.0" encoding="UTF-8"?><rpc-reply message-id="urn:uuid:57e983f4-3e15-4004-89aa-47f6ef985810" xmlns="urn:ietf:params:netconf:base:1.0"><data><cli-config-data-block>!
# version 15.2
# service timestamps debug datetime msec
# service timestamps log datetime msec
# !
# hostname Lab8Router
# !
# boot-start-marker
# boot-end-marker
# !
# !
# !
# no aaa new-model
# no ip icmp rate-limit unreachable
# ip cef
# !
# !
# !
# !
# !
# !
# no ip domain lookup
# ip domain name ankit_lab8
# no ipv6 cef
# !
# !
# multilink bundle-name authenticated
# !
# !
# !
# !
# !
# !
# !
# username ankit privilege 15 password 0 lab8
# !
# !
# ip tcp synwait-time 5
# ip ssh version 2
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# interface Loopback10
#  ip address 10.1.1.1 255.255.255.255
# !
# interface FastEthernet0/0
#  ip address 198.51.100.1 255.255.255.0
#  duplex full
# !
# interface FastEthernet1/0
#  no ip address
#  shutdown
#  speed auto
#  duplex auto
# !
# interface FastEthernet1/1
#  no ip address
#  shutdown
#  speed auto
#  duplex auto
# !
# interface FastEthernet2/0
#  no ip address
#  shutdown
#  speed auto
#  duplex auto
# !
# interface FastEthernet2/1
#  no ip address
#  shutdown
#  speed auto
#  duplex auto
# !
# interface GigabitEthernet3/0
#  no ip address
#  shutdown
#  negotiation auto
# !
# ip forward-protocol nd
# !
# !
# no ip http server
# no ip http secure-server
# !
# !
# !
# !
# control-plane
# !
# !
# line con 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line aux 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line vty 0 4
#  login local
#  transport input ssh
# line vty 5 15
#  login local
#  transport input ssh
# !
# netconf ssh
# !
# </cli-config-data-block></data></rpc-reply>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-63533176a0b1> in <module>
#       5 print(c)
#       6 m.close_session()
# ----> 7 print(f'Interface name: { cli-config-data-block["name"]["#text"] }')
#
# NameError: name 'cli' is not defined

# %%
from ncclient import manager
from pprint import pprint
import xmltodict
import xml.dom.minidom


m = manager.connect(host='198.51.100.1', port=22, username='ankit', password='lab8', hostkey_verify=False, allow_agent=False, look_for_keys=True, device_params={'name':'iosxr'})

running_config = m.get_config(source="running")

running_config_xml = xmltodict.parse(running_config.xml)["rpc-reply"]["data"]
print(xml.dom.minidom.parseString(str(running_config)).toprettyxml())
# Out:
# <?xml version="1.0" ?>
# <rpc-reply message-id="urn:uuid:2bab24d3-9e0f-4d53-a285-e22a52f89add" xmlns="urn:ietf:params:netconf:base:1.0">
# 	<data>
# 		<cli-config-data-block>!
# version 15.2
# service timestamps debug datetime msec
# service timestamps log datetime msec
# !
# hostname Lab8Router
# !
# boot-start-marker
# boot-end-marker
# !
# !
# !
# no aaa new-model
# no ip icmp rate-limit unreachable
# ip cef
# !
# !
# !
# !
# !
# !
# no ip domain lookup
# ip domain name ankit_lab8
# no ipv6 cef
# !
# !
# multilink bundle-name authenticated
# !
# !
# !
# !
# !
# !
# !
# username ankit privilege 15 password 0 lab8
# !
# !
# ip tcp synwait-time 5
# ip ssh version 2
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# interface Loopback10
#  ip address 10.1.1.1 255.255.255.255
# !
# interface FastEthernet0/0
#  ip address 198.51.100.1 255.255.255.0
#  duplex full
# !
# interface FastEthernet1/0
#  no ip address
#  shutdown
#  speed auto
#  duplex auto
# !
# interface FastEthernet1/1
#  no ip address
#  shutdown
#  speed auto
#  duplex auto
# !
# interface FastEthernet2/0
#  no ip address
#  shutdown
#  speed auto
#  duplex auto
# !
# interface FastEthernet2/1
#  no ip address
#  shutdown
#  speed auto
#  duplex auto
# !
# interface GigabitEthernet3/0
#  no ip address
#  shutdown
#  negotiation auto
# !
# ip forward-protocol nd
# !
# !
# no ip http server
# no ip http secure-server
# !
# !
# !
# !
# control-plane
# !
# !
# line con 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line aux 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line vty 0 4
#  login local
#  transport input ssh
# line vty 5 15
#  login local
#  transport input ssh
# !
# netconf ssh
# !
# end
# </cli-config-data-block>
# 	</data>
# </rpc-reply>

# %%
from ncclient import manager
import re

m = manager.connect(host='198.51.100.1', port=22, username='ankit', password='lab8', hostkey_verify=False, allow_agent=False, look_for_keys=True, device_params={'name':'iosxr'})
c = m.get_config(source='running')
print(str(c))
loopback1 = re.findall("\W*(10.1.1.1)\W*",str(c))
ips = re.findall("\d+\.\d+\.\d+\.\d+",str(c))
print(loopback1)
m.close_session()
print(ips)
# Out:
# <?xml version="1.0" encoding="UTF-8"?><rpc-reply message-id="urn:uuid:c0a5de46-70ac-4326-bd5c-773047e523fe" xmlns="urn:ietf:params:netconf:base:1.0"><data><cli-config-data-block>!
# ! Last configuration change at 03:07:00 UTC Tue Nov 2 2021
# !
# version 15.2
# service timestamps debug datetime msec
# service timestamps log datetime msec
# !
# hostname Lab8Router
# !
# boot-start-marker
# boot-end-marker
# !
# !
# !
# no aaa new-model
# no ip icmp rate-limit unreachable
# ip cef
# !
# !
# !
# !
# !
# !
# no ip domain lookup
# ip domain name ankit_lab8
# no ipv6 cef
# !
# !
# multilink bundle-name authenticated
# !
# !
# !
# !
# !
# !
# !
# username ankit privilege 15 password 0 lab8
# !
# !
# ip tcp synwait-time 5
# ip ssh version 2
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# !
# interface Loopback10
#  ip address 10.1.1.1 255.255.255.255
# !
# interface FastEthernet0/0
#  ip address 198.51.100.1 255.255.255.0
#  duplex full
# !
# interface FastEthernet1/0
#  no ip address
#  shutdown
#  speed auto
#  duplex auto
# !
# interface FastEthernet1/1
#  no ip address
#  shutdown
#  speed auto
#  duplex auto
# !
# interface FastEthernet2/0
#  no ip address
#  shutdown
#  speed auto
#  duplex auto
# !
# interface FastEthernet2/1
#  no ip address
#  shutdown
#  speed auto
#  duplex auto
# !
# interface GigabitEthernet3/0
#  no ip address
#  shutdown
#  negotiation auto
# !
# ip forward-protocol nd
# !
# !
# no ip http server
# no ip http secure-server
# !
# !
# !
# !
# control-plane
# !
# !
# line con 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line aux 0
#  exec-timeout 0 0
#  privilege level 15
#  logging synchronous
#  stopbits 1
# line vty 0 4
#  login local
#  transport input ssh
# line vty 5 15
#  login local
#  transport input ssh
# !
# netconf max-sessions 16
# netconf ssh
# !
# </cli-config-data-block></data></rpc-reply>
# ['10.1.1.1']
# ['10.1.1.1', '255.255.255.255', '198.51.100.1', '255.255.255.0']

# %%
from ncclient import manager
import re
# Create filter template for an interface
loopback = """
<filter>
<config-format-text-block>
<text-filter-spec> interface Loopback10 </text-filter-spec>
</config-format-text-block>
</filter>
"""

m = manager.connect(host='198.51.100.1', port=22, username='ankit', password='lab8', hostkey_verify=False, allow_agent=False, look_for_keys=True, device_params={'name':'iosxr'})

r = m.get_config("running", loopback)
ips = re.findall("\d+\.\d+\.\d+\.\d+",str(r))
m.close_session()
print(ips)
# Out:
# ['10.1.1.1', '255.255.255.255']

# %%
from ncclient import manager
import re
# Create filter template for an interface
ospf = """
<filter>
<config-format-text-block>
<text-filter-spec> | sec ospf </text-filter-spec>
</config-format-text-block>
</filter>
"""

m = manager.connect(host='198.51.100.1', port=22, username='ankit', password='lab8', hostkey_verify=False, allow_agent=False, look_for_keys=True, device_params={'name':'iosxr'})

r = m.get_config("running", ospf)
ips = re.findall("\d+\.\d+\.\d+\.\d+",str(r))
area = re.findall("\w+\ \d+",str(r))
m.close_session()
print(ips)
print(area[-1][-1])
# Out:
# ['198.51.100.0', '0.0.0.255']
# 0

# %%
from ncclient import manager
import re
# Create filter template for an interface
#hostname = """
#<filter>
#<config-format-text-block>
#<text-filter-spec> | inc hostname </text-filter-spec>
#</config-format-text-block>
#</filter>
#"""

m = manager.connect(host='198.51.100.1', port=22, username='ankit', password='lab8', hostkey_verify=False, allow_agent=False, look_for_keys=True, device_params={'name':'iosxr'})

r = m.get_config("running")
name = re.findall("^hostname\s\w+$",str(r))
m.close_session()
print(name)
# Out:
# []

# %%
import csv
from ncclient import manager

hosts=[]
hostnames=[]
loopbackIPs=[]
loopbackSubnets=[]
OSPFareas=[]
OSPFnetworks=[]
Wildmasks=[]
with open("lab8-obj2-conf.csv","r") as file:
    reader = csv.DictReader(file)
    for row in reader:
        if row:
            hosts.append(row["RouterIP"])
            hostnames.append(row["Hostname"])
            loopbackIPs.append(row["Loopback99IP"])
            loopbackSubnets.append(row["LoopbackSubnet"])
            OSPFareas.append(row["OSPFarea"])
            OSPFnetworks.append(row["OSPFNetwork"])
            Wildmasks.append(row["WildMask"])


CONFIG_COMMANDS = """
    <config>
        <cli-config-data>
            <cmd>hostname %s</cmd>
            <cmd>interface Loopback99</cmd>
            <cmd>ip address %s %s</cmd>
            <cmd>router ospf 1</cmd>
            <cmd>network %s %s area %s</cmd>
        </cli-config-data>
    </config>
"""
    

def update_config(conn, hostname, loopbackip, loopbacksubnet, OSPFnetwork, Wildmask, area):
    config_str = CONFIG_COMMANDS % (hostname, loopbackip, loopbacksubnet, OSPFnetwork, Wildmask, area)
    conn.edit_config(target='running', config=config_str)
    print(f'{hostname} configured.')

for (host, hostname, loopbackip, loopbacksubnet, OSPFnetwork, Wildmask, area) in zip(hosts, hostnames, loopbackIPs, loopbackSubnets, OSPFnetworks, Wildmasks, OSPFareas):
    conn = manager.connect(host=host, port=22, username='lab', password='lab123', hostkey_verify=False, allow_agent=False, look_for_keys=True, device_params={'name':'iosxr'})
    update_config(conn, hostname, loopbackip, loopbacksubnet, OSPFnetwork, Wildmask, area)
# Out:
# Router1 configured.
# Router2 configured.
# Router3 configured.
# Router4 configured.
# Router5 configured.

# %%
from ncclient import manager
from prettytable import PrettyTable
import re

loopback = """
<filter>
<config-format-text-block>
<text-filter-spec> interface Loopback99 </text-filter-spec>
</config-format-text-block>
</filter>
"""

ospf = """
<filter>
<config-format-text-block>
<text-filter-spec> | sec ospf </text-filter-spec>
</config-format-text-block>
</filter>
"""

m = manager.connect(host='198.51.100.11', port=22, username='lab', password='lab123', hostkey_verify=False, allow_agent=False, look_for_keys=True, device_params={'name':'iosxr'})

r1 = m.get_config("running", loopback)
loopback_info = re.findall("\d+\.\d+\.\d+\.\d+",str(r1))
r2 = m.get_config("running", ospf)
ospf_network_info = re.findall("\d+\.\d+\.\d+\.\d+",str(r2))
#ospf_area = re.findall("\w+\ \d+",str(r))
m.close_session()
print(loopback_info)
print(ospf_network_info)
#print(ospf_area[-1][-1])
#print(ospf_area)

table = PrettyTable(["Hostname", "Loopback99IP", "LoopbackSubnet", "OSPFnetwork", "OSPFWildMask", "OSPFArea"])
table.add_row(["Router1", f"{loopback_info[0]}", f"{loopback_info[1]}", f"{ospf_network_info[0]}", f"{ospf_network_info[1]}", "0"])
print(table)
# Out:
# ['10.1.1.1', '255.255.255.0']
# ['10.1.1.0', '0.0.0.255']
# +----------+--------------+----------------+-------------+--------------+----------+
# | Hostname | Loopback99IP | LoopbackSubnet | OSPFnetwork | OSPFWildMask | OSPFArea |
# +----------+--------------+----------------+-------------+--------------+----------+
# | Router1  |   10.1.1.1   | 255.255.255.0  |   10.1.1.0  |  0.0.0.255   |    0     |
# +----------+--------------+----------------+-------------+--------------+----------+

# %%
from ncclient import manager
from prettytable import PrettyTable
import re

loopback = """
<filter>
<config-format-text-block>
<text-filter-spec> interface Loopback99 </text-filter-spec>
</config-format-text-block>
</filter>
"""

ospf = """
<filter>
<config-format-text-block>
<text-filter-spec> | sec ospf </text-filter-spec>
</config-format-text-block>
</filter>
"""

loopback_IP=[]
loopback_subnet=[]
ospf_network=[]
ospf_wildmask=[]
hosts=['198.51.100.11', '198.51.100.12', '198.51.100.13', '198.51.100.14', '198.51.100.15']
for host in hosts:
    m = manager.connect(host=host, port=22, username='lab', password='lab123', hostkey_verify=False, allow_agent=False, look_for_keys=True, device_params={'name':'iosxr'})
    r1 = m.get_config("running", loopback)
    loopback_info = re.findall("\d+\.\d+\.\d+\.\d+",str(r1))
    r2 = m.get_config("running", ospf)
    ospf_network_info = re.findall("\d+\.\d+\.\d+\.\d+",str(r2))
    m.close_session()
    print(loopback_info)
    print(ospf_network_info)
    loopback_IP.append(loopback_info[0])
    loopback_subnet.append(loopback_info[1])
    ospf_network.append(ospf_network_info[0])
    ospf_wildmask.append(ospf_network_info[1])

print(loopback_IP)
print(loopback_subnet)
print(ospf_network)
print(ospf_wildmask)

hostnames=['Router1', 'Router2', 'Router3', 'Router4', 'Router5']
table = PrettyTable(["Hostname", "Loopback99IP", "LoopbackSubnet", "OSPFnetwork", "OSPFWildMask", "OSPFArea"])
for i in range(0,len(hostnames)):
    table.add_row([hostnames[i], f"{loopback_IP[i]}", f"{loopback_subnet[i]}", f"{ospf_network[i]}", f"{ospf_wildmask[i]}", "0"])
print(table)
# Out:
# ['10.1.1.1', '255.255.255.0']
# ['10.1.1.0', '0.0.0.255']
# ['10.1.2.1', '255.255.255.0']
# ['10.1.2.0', '0.0.0.255']
# ['10.1.3.1', '255.255.255.0']
# ['10.1.3.0', '0.0.0.255']
# ['10.1.4.1', '255.255.255.0']
# ['10.1.4.0', '0.0.0.255']
# ['10.1.5.1', '255.255.255.0']
# ['10.1.5.0', '0.0.0.255']
# ['10.1.1.1', '10.1.2.1', '10.1.3.1', '10.1.4.1', '10.1.5.1']
# ['255.255.255.0', '255.255.255.0', '255.255.255.0', '255.255.255.0', '255.255.255.0']
# ['10.1.1.0', '10.1.2.0', '10.1.3.0', '10.1.4.0', '10.1.5.0']
# ['0.0.0.255', '0.0.0.255', '0.0.0.255', '0.0.0.255', '0.0.0.255']
# +----------+--------------+----------------+-------------+--------------+----------+
# | Hostname | Loopback99IP | LoopbackSubnet | OSPFnetwork | OSPFWildMask | OSPFArea |
# +----------+--------------+----------------+-------------+--------------+----------+
# | Router1  |   10.1.1.1   | 255.255.255.0  |   10.1.1.0  |  0.0.0.255   |    0     |
# | Router2  |   10.1.2.1   | 255.255.255.0  |   10.1.2.0  |  0.0.0.255   |    0     |
# | Router3  |   10.1.3.1   | 255.255.255.0  |   10.1.3.0  |  0.0.0.255   |    0     |
# | Router4  |   10.1.4.1   | 255.255.255.0  |   10.1.4.0  |  0.0.0.255   |    0     |
# | Router5  |   10.1.5.1   | 255.255.255.0  |   10.1.5.0  |  0.0.0.255   |    0     |
# +----------+--------------+----------------+-------------+--------------+----------+

# %%
import csv

def main(file):
    hosts=[]
    hostname=[]
    loopbackIP=[]
    loopbackSubnet=[]
    OSPFarea=[]
    OSPFnetwork=[]
    Wildmask=[]
    with open(f"{file}","r") as file:
        reader = csv.DictReader(file)
        for row in reader:
            if row:
                hosts.append(row["RouterIP"])
                hostname.append(row["Hostname"])
                loopbackIP.append(row["Loopback99IP"])
                loopbackSubnet.append(row["LoopbackSubnet"])
                OSPFarea.append(row["OSPFarea"])
                OSPFnetwork.append(row["OSPFNetwork"])
                Wildmask.append(row["WildMask"])
    print(hosts)
    print(hostname)
    print(loopbackIP)
    print(loopbackSubnet)
    print(OSPFarea)
    print(OSPFnetwork)
    print(Wildmask)

if __name__ == "__main__":
    main("lab8-obj2-conf.csv")
# Out:
# ['198.51.100.11', '198.51.100.12', '198.51.100.13', '198.51.100.14', '198.51.100.15']
# ['Router1', 'Router2', 'Router3', 'Router4', 'Router5']
# ['10.1.1.1', '10.1.2.1', '10.1.3.1', '10.1.4.1', '10.1.5.1']
# ['255.255.255.0', '255.255.255.0', '255.255.255.0', '255.255.255.0', '255.255.255.0']
# ['0', '0', '0', '0', '0']
# ['10.1.1.0', '10.1.2.0', '10.1.3.0', '10.1.4.0', '10.1.5.0']
# ['0.0.0.255', '0.0.0.255', '0.0.0.255', '0.0.0.255', '0.0.0.255']

# %%
from ncclient import manager

m = manager.connect(host='198.51.100.1', port=22, username='netman', password='netman', hostkey_verify=False, allow_agent=False, look_for_keys=True, device_params={'name':'iosxr'})
c = m.get_config(source='running')
print(c)
m.close_session()
# Out:
# <?xml version="1.0"?>
# <rpc-reply message-id="urn:uuid:acc427c0-b3ef-46be-8cdb-785dba64714f" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns="urn:ietf:params:xml:ns:netconf:base:1.0">
#  <data>
#   <aaa xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-aaa-lib-cfg">
#    <usernames xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-aaa-locald-cfg">
#     <username>
#      <name>ankit</name>
#      <password>000812045C</password>
#     </username>
#    </usernames>
#    <authorizations>
#     <authorization>
#      <type>exec</type>
#      <listname>default</listname>
#      <method>local</method>
#     </authorization>
#    </authorizations>
#   </aaa>
#   <aaa xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-aaa-locald-admin-cfg">
#    <usernames>
#     <username>
#      <name>netman</name>
#      <usergroup-under-usernames>
#       <usergroup-under-username>
#        <name>root-system</name>
#       </usergroup-under-username>
#      </usergroup-under-usernames>
#      <secret>$1$szek$AIJ5miQR2vROWYbA20u.U0</secret>
#     </username>
#    </usernames>
#   </aaa>
#   <crypto xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-crypto-sam-cfg">
#    <ssh xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-crypto-ssh-cfg">
#     <server>
#      <v2></v2>
#      <netconf-vrf-table>
#       <vrf>
#        <vrf-name>default</vrf-name>
#        <enable></enable>
#       </vrf>
#      </netconf-vrf-table>
#     </server>
#    </ssh>
#   </crypto>
#   <interface-configurations xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-ifmgr-cfg">
#    <interface-configuration>
#     <active>act</active>
#     <interface-name>MgmtEth0/0/CPU0/0</interface-name>
#     <shutdown></shutdown>
#    </interface-configuration>
#    <interface-configuration>
#     <active>act</active>
#     <interface-name>GigabitEthernet0/0/0/0</interface-name>
#     <ipv4-network xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-io-cfg">
#      <addresses>
#       <primary>
#        <address>198.51.100.1</address>
#        <netmask>255.255.255.0</netmask>
#       </primary>
#      </addresses>
#     </ipv4-network>
#    </interface-configuration>
#    <interface-configuration>
#     <active>act</active>
#     <interface-name>GigabitEthernet0/0/0/1</interface-name>
#     <shutdown></shutdown>
#    </interface-configuration>
#    <interface-configuration>
#     <active>act</active>
#     <interface-name>GigabitEthernet0/0/0/2</interface-name>
#     <shutdown></shutdown>
#    </interface-configuration>
#    <interface-configuration>
#     <active>act</active>
#     <interface-name>GigabitEthernet0/0/0/3</interface-name>
#     <shutdown></shutdown>
#    </interface-configuration>
#    <interface-configuration>
#     <active>act</active>
#     <interface-name>GigabitEthernet0/0/0/4</interface-name>
#     <shutdown></shutdown>
#    </interface-configuration>
#    <interface-configuration>
#     <active>act</active>
#     <interface-name>GigabitEthernet0/0/0/5</interface-name>
#     <shutdown></shutdown>
#    </interface-configuration>
#    <interface-configuration>
#     <active>act</active>
#     <interface-name>GigabitEthernet0/0/0/6</interface-name>
#     <shutdown></shutdown>
#    </interface-configuration>
#    <interface-configuration>
#     <active>act</active>
#     <interface-name>GigabitEthernet0/0/0/7</interface-name>
#     <shutdown></shutdown>
#    </interface-configuration>
#   </interface-configurations>
#   <interfaces xmlns="http://openconfig.net/yang/interfaces">
#    <interface>
#     <name>MgmtEth0/0/CPU0/0</name>
#     <config>
#      <name>MgmtEth0/0/CPU0/0</name>
#      <type xmlns:idx="urn:ietf:params:xml:ns:yang:iana-if-type">idx:ethernetCsmacd</type>
#      <enabled>false</enabled>
#     </config>
#     <ethernet xmlns="http://openconfig.net/yang/interfaces/ethernet">
#      <config>
#       <auto-negotiate>false</auto-negotiate>
#      </config>
#     </ethernet>
#    </interface>
#    <interface>
#     <name>GigabitEthernet0/0/0/0</name>
#     <config>
#      <name>GigabitEthernet0/0/0/0</name>
#      <type xmlns:idx="urn:ietf:params:xml:ns:yang:iana-if-type">idx:ethernetCsmacd</type>
#      <enabled>true</enabled>
#     </config>
#     <ethernet xmlns="http://openconfig.net/yang/interfaces/ethernet">
#      <config>
#       <auto-negotiate>false</auto-negotiate>
#      </config>
#     </ethernet>
#     <subinterfaces>
#      <subinterface>
#       <index>0</index>
#       <ipv4 xmlns="http://openconfig.net/yang/interfaces/ip">
#        <address>
#         <ip>198.51.100.1</ip>
#         <config>
#          <ip>198.51.100.1</ip>
#          <prefix-length>24</prefix-length>
#         </config>
#        </address>
#       </ipv4>
#      </subinterface>
#     </subinterfaces>
#    </interface>
#    <interface>
#     <name>GigabitEthernet0/0/0/1</name>
#     <config>
#      <name>GigabitEthernet0/0/0/1</name>
#      <type xmlns:idx="urn:ietf:params:xml:ns:yang:iana-if-type">idx:ethernetCsmacd</type>
#      <enabled>false</enabled>
#     </config>
#     <ethernet xmlns="http://openconfig.net/yang/interfaces/ethernet">
#      <config>
#       <auto-negotiate>false</auto-negotiate>
#      </config>
#     </ethernet>
#    </interface>
#    <interface>
#     <name>GigabitEthernet0/0/0/2</name>
#     <config>
#      <name>GigabitEthernet0/0/0/2</name>
#      <type xmlns:idx="urn:ietf:params:xml:ns:yang:iana-if-type">idx:ethernetCsmacd</type>
#      <enabled>false</enabled>
#     </config>
#     <ethernet xmlns="http://openconfig.net/yang/interfaces/ethernet">
#      <config>
#       <auto-negotiate>false</auto-negotiate>
#      </config>
#     </ethernet>
#    </interface>
#    <interface>
#     <name>GigabitEthernet0/0/0/3</name>
#     <config>
#      <name>GigabitEthernet0/0/0/3</name>
#      <type xmlns:idx="urn:ietf:params:xml:ns:yang:iana-if-type">idx:ethernetCsmacd</type>
#      <enabled>false</enabled>
#     </config>
#     <ethernet xmlns="http://openconfig.net/yang/interfaces/ethernet">
#      <config>
#       <auto-negotiate>false</auto-negotiate>
#      </config>
#     </ethernet>
#    </interface>
#    <interface>
#     <name>GigabitEthernet0/0/0/4</name>
#     <config>
#      <name>GigabitEthernet0/0/0/4</name>
#      <type xmlns:idx="urn:ietf:params:xml:ns:yang:iana-if-type">idx:ethernetCsmacd</type>
#      <enabled>false</enabled>
#     </config>
#     <ethernet xmlns="http://openconfig.net/yang/interfaces/ethernet">
#      <config>
#       <auto-negotiate>false</auto-negotiate>
#      </config>
#     </ethernet>
#    </interface>
#    <interface>
#     <name>GigabitEthernet0/0/0/5</name>
#     <config>
#      <name>GigabitEthernet0/0/0/5</name>
#      <type xmlns:idx="urn:ietf:params:xml:ns:yang:iana-if-type">idx:ethernetCsmacd</type>
#      <enabled>false</enabled>
#     </config>
#     <ethernet xmlns="http://openconfig.net/yang/interfaces/ethernet">
#      <config>
#       <auto-negotiate>false</auto-negotiate>
#      </config>
#     </ethernet>
#    </interface>
#    <interface>
#     <name>GigabitEthernet0/0/0/6</name>
#     <config>
#      <name>GigabitEthernet0/0/0/6</name>
#      <type xmlns:idx="urn:ietf:params:xml:ns:yang:iana-if-type">idx:ethernetCsmacd</type>
#      <enabled>false</enabled>
#     </config>
#     <ethernet xmlns="http://openconfig.net/yang/interfaces/ethernet">
#      <config>
#       <auto-negotiate>false</auto-negotiate>
#      </config>
#     </ethernet>
#    </interface>
#    <interface>
#     <name>GigabitEthernet0/0/0/7</name>
#     <config>
#      <name>GigabitEthernet0/0/0/7</name>
#      <type xmlns:idx="urn:ietf:params:xml:ns:yang:iana-if-type">idx:ethernetCsmacd</type>
#      <enabled>false</enabled>
#     </config>
#     <ethernet xmlns="http://openconfig.net/yang/interfaces/ethernet">
#      <config>
#       <auto-negotiate>false</auto-negotiate>
#      </config>
#     </ethernet>
#    </interface>
#   </interfaces>
#   <netconf-yang xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-man-netconf-cfg">
#    <agent>
#     <ssh>
#      <enable></enable>
#     </ssh>
#    </agent>
#   </netconf-yang>
#  </data>
# </rpc-reply>
# <?xml version="1.0"?>
# <rpc-reply message-id="urn:uuid:2c8741fa-7656-46cb-8a8d-47c99140cd9c" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns="urn:ietf:params:xml:ns:netconf:base:1.0">
#  <ok/>
# </rpc-reply>

# %%
from ncclient import manager

m = manager.connect(host='198.51.100.1', port=22, username='netman', password='netman', hostkey_verify=False, allow_agent=False, look_for_keys=True, device_params={'name':'iosxr'})
c = m.get_config(source='candidate')
print(c)
m.close_session()
# Out:
# <?xml version="1.0"?>
# <rpc-reply message-id="urn:uuid:ddc815de-27bc-4b89-8afc-5290966512a4" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns="urn:ietf:params:xml:ns:netconf:base:1.0">
#  <data>
#   <aaa xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-aaa-lib-cfg">
#    <usernames xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-aaa-locald-cfg">
#     <username>
#      <name>ankit</name>
#      <password>000812045C</password>
#     </username>
#    </usernames>
#    <authorizations>
#     <authorization>
#      <type>exec</type>
#      <listname>default</listname>
#      <method>local</method>
#     </authorization>
#    </authorizations>
#   </aaa>
#   <aaa xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-aaa-locald-admin-cfg">
#    <usernames>
#     <username>
#      <name>netman</name>
#      <usergroup-under-usernames>
#       <usergroup-under-username>
#        <name>root-system</name>
#       </usergroup-under-username>
#      </usergroup-under-usernames>
#      <secret>$1$szek$AIJ5miQR2vROWYbA20u.U0</secret>
#     </username>
#    </usernames>
#   </aaa>
#   <crypto xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-crypto-sam-cfg">
#    <ssh xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-crypto-ssh-cfg">
#     <server>
#      <v2></v2>
#      <netconf-vrf-table>
#       <vrf>
#        <vrf-name>default</vrf-name>
#        <enable></enable>
#       </vrf>
#      </netconf-vrf-table>
#     </server>
#    </ssh>
#   </crypto>
#   <interface-configurations xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-ifmgr-cfg">
#    <interface-configuration>
#     <active>act</active>
#     <interface-name>MgmtEth0/0/CPU0/0</interface-name>
#     <shutdown></shutdown>
#    </interface-configuration>
#    <interface-configuration>
#     <active>act</active>
#     <interface-name>GigabitEthernet0/0/0/0</interface-name>
#     <ipv4-network xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-io-cfg">
#      <addresses>
#       <primary>
#        <address>198.51.100.1</address>
#        <netmask>255.255.255.0</netmask>
#       </primary>
#      </addresses>
#     </ipv4-network>
#     <ipv4-packet-filter xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-ip-pfilter-cfg">
#      <inbound>
#       <acl-name-array>acl_1</acl-name-array>
#       <is-common-array>false</is-common-array>
#      </inbound>
#     </ipv4-packet-filter>
#    </interface-configuration>
#    <interface-configuration>
#     <active>act</active>
#     <interface-name>GigabitEthernet0/0/0/1</interface-name>
#     <shutdown></shutdown>
#    </interface-configuration>
#    <interface-configuration>
#     <active>act</active>
#     <interface-name>GigabitEthernet0/0/0/2</interface-name>
#     <shutdown></shutdown>
#    </interface-configuration>
#    <interface-configuration>
#     <active>act</active>
#     <interface-name>GigabitEthernet0/0/0/3</interface-name>
#     <shutdown></shutdown>
#    </interface-configuration>
#    <interface-configuration>
#     <active>act</active>
#     <interface-name>GigabitEthernet0/0/0/4</interface-name>
#     <shutdown></shutdown>
#    </interface-configuration>
#    <interface-configuration>
#     <active>act</active>
#     <interface-name>GigabitEthernet0/0/0/5</interface-name>
#     <shutdown></shutdown>
#    </interface-configuration>
#    <interface-configuration>
#     <active>act</active>
#     <interface-name>GigabitEthernet0/0/0/6</interface-name>
#     <shutdown></shutdown>
#    </interface-configuration>
#    <interface-configuration>
#     <active>act</active>
#     <interface-name>GigabitEthernet0/0/0/7</interface-name>
#     <shutdown></shutdown>
#    </interface-configuration>
#   </interface-configurations>
#   <ipv4-acl-and-prefix-list xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-acl-cfg">
#    <accesses>
#     <access>
#      <access-list-name>acl_1</access-list-name>
#      <access-list-entries>
#       <access-list-entry>
#        <sequence-number>10</sequence-number>
#        <grant>permit</grant>
#        <source-network>
#         <source-address>198.51.100.2</source-address>
#         <source-wild-card-bits>0.0.0.255</source-wild-card-bits>
#        </source-network>
#        <sequence-str>10</sequence-str>
#       </access-list-entry>
#      </access-list-entries>
#     </access>
#    </accesses>
#   </ipv4-acl-and-prefix-list>
#   <netconf-yang xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-man-netconf-cfg">
#    <agent>
#     <ssh>
#      <enable></enable>
#     </ssh>
#    </agent>
#   </netconf-yang>
#   <host-names xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-shellutil-cfg">
#    <host-name>new2</host-name>
#   </host-names>
#   <interfaces xmlns="http://openconfig.net/yang/interfaces">
#    <interface>
#     <name>MgmtEth0/0/CPU0/0</name>
#     <config>
#      <name>MgmtEth0/0/CPU0/0</name>
#      <type xmlns:idx="urn:ietf:params:xml:ns:yang:iana-if-type">idx:ethernetCsmacd</type>
#      <enabled>false</enabled>
#     </config>
#     <ethernet xmlns="http://openconfig.net/yang/interfaces/ethernet">
#      <config>
#       <auto-negotiate>false</auto-negotiate>
#      </config>
#     </ethernet>
#    </interface>
#    <interface>
#     <name>GigabitEthernet0/0/0/0</name>
#     <config>
#      <name>GigabitEthernet0/0/0/0</name>
#      <type xmlns:idx="urn:ietf:params:xml:ns:yang:iana-if-type">idx:ethernetCsmacd</type>
#      <enabled>true</enabled>
#     </config>
#     <ethernet xmlns="http://openconfig.net/yang/interfaces/ethernet">
#      <config>
#       <auto-negotiate>false</auto-negotiate>
#      </config>
#     </ethernet>
#     <subinterfaces>
#      <subinterface>
#       <index>0</index>
#       <ipv4 xmlns="http://openconfig.net/yang/interfaces/ip">
#        <address>
#         <ip>198.51.100.1</ip>
#         <config>
#          <ip>198.51.100.1</ip>
#          <prefix-length>24</prefix-length>
#         </config>
#        </address>
#       </ipv4>
#      </subinterface>
#     </subinterfaces>
#    </interface>
#    <interface>
#     <name>GigabitEthernet0/0/0/1</name>
#     <config>
#      <name>GigabitEthernet0/0/0/1</name>
#      <type xmlns:idx="urn:ietf:params:xml:ns:yang:iana-if-type">idx:ethernetCsmacd</type>
#      <enabled>false</enabled>
#     </config>
#     <ethernet xmlns="http://openconfig.net/yang/interfaces/ethernet">
#      <config>
#       <auto-negotiate>false</auto-negotiate>
#      </config>
#     </ethernet>
#    </interface>
#    <interface>
#     <name>GigabitEthernet0/0/0/2</name>
#     <config>
#      <name>GigabitEthernet0/0/0/2</name>
#      <type xmlns:idx="urn:ietf:params:xml:ns:yang:iana-if-type">idx:ethernetCsmacd</type>
#      <enabled>false</enabled>
#     </config>
#     <ethernet xmlns="http://openconfig.net/yang/interfaces/ethernet">
#      <config>
#       <auto-negotiate>false</auto-negotiate>
#      </config>
#     </ethernet>
#    </interface>
#    <interface>
#     <name>GigabitEthernet0/0/0/3</name>
#     <config>
#      <name>GigabitEthernet0/0/0/3</name>
#      <type xmlns:idx="urn:ietf:params:xml:ns:yang:iana-if-type">idx:ethernetCsmacd</type>
#      <enabled>false</enabled>
#     </config>
#     <ethernet xmlns="http://openconfig.net/yang/interfaces/ethernet">
#      <config>
#       <auto-negotiate>false</auto-negotiate>
#      </config>
#     </ethernet>
#    </interface>
#    <interface>
#     <name>GigabitEthernet0/0/0/4</name>
#     <config>
#      <name>GigabitEthernet0/0/0/4</name>
#      <type xmlns:idx="urn:ietf:params:xml:ns:yang:iana-if-type">idx:ethernetCsmacd</type>
#      <enabled>false</enabled>
#     </config>
#     <ethernet xmlns="http://openconfig.net/yang/interfaces/ethernet">
#      <config>
#       <auto-negotiate>false</auto-negotiate>
#      </config>
#     </ethernet>
#    </interface>
#    <interface>
#     <name>GigabitEthernet0/0/0/5</name>
#     <config>
#      <name>GigabitEthernet0/0/0/5</name>
#      <type xmlns:idx="urn:ietf:params:xml:ns:yang:iana-if-type">idx:ethernetCsmacd</type>
#      <enabled>false</enabled>
#     </config>
#     <ethernet xmlns="http://openconfig.net/yang/interfaces/ethernet">
#      <config>
#       <auto-negotiate>false</auto-negotiate>
#      </config>
#     </ethernet>
#    </interface>
#    <interface>
#     <name>GigabitEthernet0/0/0/6</name>
#     <config>
#      <name>GigabitEthernet0/0/0/6</name>
#      <type xmlns:idx="urn:ietf:params:xml:ns:yang:iana-if-type">idx:ethernetCsmacd</type>
#      <enabled>false</enabled>
#     </config>
#     <ethernet xmlns="http://openconfig.net/yang/interfaces/ethernet">
#      <config>
#       <auto-negotiate>false</auto-negotiate>
#      </config>
#     </ethernet>
#    </interface>
#    <interface>
#     <name>GigabitEthernet0/0/0/7</name>
#     <config>
#      <name>GigabitEthernet0/0/0/7</name>
#      <type xmlns:idx="urn:ietf:params:xml:ns:yang:iana-if-type">idx:ethernetCsmacd</type>
#      <enabled>false</enabled>
#     </config>
#     <ethernet xmlns="http://openconfig.net/yang/interfaces/ethernet">
#      <config>
#       <auto-negotiate>false</auto-negotiate>
#      </config>
#     </ethernet>
#    </interface>
#   </interfaces>
#  </data>
# </rpc-reply>
# <?xml version="1.0"?>
# <rpc-reply message-id="urn:uuid:51bbab10-d052-4be6-b37d-9ce37aae609a" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns="urn:ietf:params:xml:ns:netconf:base:1.0">
#  <ok/>
# </rpc-reply>

# %%
from ncclient import manager

m = manager.connect(host='198.51.100.1', port=22, username='netman', password='netman', hostkey_verify=False, allow_agent=False, look_for_keys=True, device_params={'name':'iosxr'})

rpc='''
       <config>              
        <cli-config-data>
                <cmd>hostname new2</cmd>
        </cli-config-data>
       </config>
    '''
reply = m.edit_config(rpc, target='candidate')
print(reply)
reply = m.commit()
print(reply)
# Out:
# ---------------------------------------------------------------------------
# RPCError                                  Traceback (most recent call last)
# <ipython-input-3-89e014c9b5db> in <module>
#      10        </config>
#      11     '''
# ---> 12 reply = m.edit_config(rpc, target='candidate')
#      13 print(reply)
#      14 reply = m.commit()
#
# ~/.local/lib/python3.6/site-packages/ncclient/manager.py in execute(self, cls, *args, **kwds)
#     229                    timeout=self._timeout,
#     230                    raise_mode=self._raise_mode,
# --> 231                    huge_tree=self._huge_tree).request(*args, **kwds)
#     232
#     233     def locked(self, target):
#
# ~/.local/lib/python3.6/site-packages/ncclient/operations/edit.py in request(self, config, format, target, default_operation, test_option, error_option)
#      67             config_text = sub_ele(node, "config-text")
#      68             sub_ele(config_text, "configuration-text").text = config
# ---> 69         return self._request(node)
#      70
#      71
#
# ~/.local/lib/python3.6/site-packages/ncclient/operations/rpc.py in _request(self, op)
#     358                             raise RPCError(to_ele(self._reply._raw), errs=errors)
#     359                         else:
# --> 360                             raise self._reply.error
#     361                 if self._device_handler.transform_reply():
#     362                     return NCElement(self._reply, self._device_handler.transform_reply(), huge_tree=self._huge_tree)
#
# RPCError: {'type': 'protocol', 'tag': 'unknown-namespace', 'app_tag': None, 'severity': 'error', 'info': '<?xml version="1.0" encoding="UTF-8"?><error-info xmlns="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0">\n   <bad-element>cli-config-data</bad-element>\n   <bad-namespace/>\n  </error-info>\n ', 'path': None, 'message': None}

# %%
from ncclient import manager

m = manager.connect(host='198.51.100.1', port=22, username='netman', password='netman', hostkey_verify=False, allow_agent=False, look_for_keys=True, device_params={'name':'iosxr'})

rpc='''
    <config xmlns:xc="urn:ietf:params:xml:ns:netconf:base:1.0">
       <ipv4-acl-and-prefix-list xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-ipv4-acl-cfg">
        <accesses>
         <access>
          <access-list-name>acl_1</access-list-name>
           <access-list-entries>
            <access-list-entry>
             <sequence-number>10</sequence-number>
             <grant>permit</grant>
             <source-network>
              <source-address>198.51.100.2</source-address>
              <source-wild-card-bits>0.0.0.255</source-wild-card-bits>
             </source-network>
             <sequence-str>10</sequence-str>
            </access-list-entry>
           </access-list-entries>
         </access>
        </accesses>
       </ipv4-acl-and-prefix-list>
    </config>
    '''
reply = m.edit_config(rpc, target='candidate')
print(reply)
reply = m.commit()
print(reply)
# Out:
# <?xml version="1.0"?>
# <rpc-reply message-id="urn:uuid:c6b5d41d-f7d6-4eef-918b-66aa990da17e" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns="urn:ietf:params:xml:ns:netconf:base:1.0">
#  <ok/>
# </rpc-reply>
#
# <?xml version="1.0"?>
# <rpc-reply message-id="urn:uuid:5c3963d4-40f9-43cd-8f61-bd4165cbecb4" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns="urn:ietf:params:xml:ns:netconf:base:1.0">
#  <ok/>
# </rpc-reply>

# %%
from ncclient import manager

m = manager.connect(host='198.51.100.1', port=22, username='netman', password='netman', hostkey_verify=False, allow_agent=False, look_for_keys=True, device_params={'name':'iosxr'})

rpc='''
    <config xmlns:xc="urn:ietf:params:xml:ns:netconf:base:1.0">
     <host-names xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-shellutil-cfg">
       <host-name>new2</host-name>
     </host-names>
    </config>
    '''
reply = m.edit_config(rpc, target='candidate')
print(reply)
reply = m.commit()
print(reply)
# Out:
# <?xml version="1.0"?>
# <rpc-reply message-id="urn:uuid:3ebbdc03-e855-47d0-be62-85ce9b74fae4" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns="urn:ietf:params:xml:ns:netconf:base:1.0">
#  <ok/>
# </rpc-reply>
#
# <?xml version="1.0"?>
# <rpc-reply message-id="urn:uuid:d213396b-295f-4695-9381-68229d1ea9ea" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns="urn:ietf:params:xml:ns:netconf:base:1.0">
#  <ok/>
# </rpc-reply>

# %%
from ncclient import manager

m = manager.connect(host='198.51.100.1', port=22, username='netman', password='netman', hostkey_verify=False, allow_agent=False, look_for_keys=True, device_params={'name':'iosxr'})

rpc='''
<config xmlns:xc="urn:ietf:params:xml:ns:netconf:base:1.0">
  <interfaces xmlns="http://openconfig.net/yang/interfaces">
   <interface>
    <name>Loopback1</name>
    <config>
     <name>Loopback1</name>
     <type xmlns:idx="urn:ietf:params:xml:ns:yang:iana-if-type">idx:softwareLoopback</type>
     <enabled>true</enabled>
    </config>
    <subinterfaces>
     <subinterface>
      <index>0</index>
      <ipv4 xmlns="http://openconfig.net/yang/interfaces/ip">
       <address>
        <ip>10.11.12.13</ip>
        <config>
         <ip>10.11.12.13</ip>
         <prefix-length>32</prefix-length>
        </config>
       </address>
      </ipv4>
     </subinterface>
    </subinterfaces>
   </interface>
  </interfaces>
</config>
'''

reply = m.edit_config(rpc, target='candidate')
print(reply)
reply = m.commit()
print(reply)
# Out:
# <?xml version="1.0"?>
# <rpc-reply message-id="urn:uuid:621cd8a4-9b1f-47d6-9e62-9af838df7b6b" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns="urn:ietf:params:xml:ns:netconf:base:1.0">
#  <ok/>
# </rpc-reply>
#
# <?xml version="1.0"?>
# <rpc-reply message-id="urn:uuid:b73a602b-9203-4f15-8a08-a7fb00435b3f" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns="urn:ietf:params:xml:ns:netconf:base:1.0">
#  <ok/>
# </rpc-reply>

# %%
from ncclient import manager

m = manager.connect(host='198.51.100.1', port=22, username='netman', password='netman', hostkey_verify=False, allow_agent=False, look_for_keys=True, device_params={'name':'iosxr'})

rpc='''
    <config xmlns:xc="urn:ietf:params:xml:ns:netconf:base:1.0">
    <interfaces xmlns="http://openconfig.net/yang/interfaces">
    <interface>
    <name>GigabitEthernet0/0/0/0</name>
    <config>
     <name>GigabitEthernet0/0/0/0</name>
     <type xmlns:idx="urn:ietf:params:xml:ns:yang:iana-if-type">idx:ethernetCsmacd</type>
     <enabled>true</enabled>
    </config>
    <ethernet xmlns="http://openconfig.net/yang/interfaces/ethernet">
     <config>
      <auto-negotiate>false</auto-negotiate>
     </config>
    </ethernet>
    <ipv4-packet-filter xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-ip-pfilter-cfg">
     <inbound>
      <acl-name-array>acl_1</acl-name-array>
      <is-common-array>false</is-common-array>
     </inbound>
    </ipv4-packet-filter>
   </interface>
   </interfaces>
    </config>
    '''
reply = m.edit_config(rpc, target='candidate')
print(reply)
reply = m.commit()
print(reply)
# Out:
# <?xml version="1.0"?>
# <rpc-reply message-id="urn:uuid:1eaf6992-36d9-41ad-805a-4497288ef149" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns="urn:ietf:params:xml:ns:netconf:base:1.0">
#  <ok/>
# </rpc-reply>
#
# <?xml version="1.0"?>
# <rpc-reply message-id="urn:uuid:3efd0b9e-dab9-4ece-a41b-f243e39559f3" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns="urn:ietf:params:xml:ns:netconf:base:1.0">
#  <ok/>
# </rpc-reply>

# %%
from ncclient import manager

m = manager.connect(host='198.51.100.1', port=22, username='netman', password='netman', hostkey_verify=False, allow_agent=False, look_for_keys=True, device_params={'name':'iosxr'})

rpc='''
    <config xmlns:xc="urn:ietf:params:xml:ns:netconf:base:1.0">
      <interfaces xmlns="http://openconfig.net/yang/interfaces">
        <interface-configuration>
            <active>act</active>
            <interface-name>GigabitEthernet0/0/0/0</interface-name>
            <ipv4-packet-filter xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-ip-pfilter-cfg">
             <inbound>
              <acl-name-array>acl_1</acl-name-array>
              <is-common-array>false</is-common-array>
             </inbound>
            </ipv4-packet-filter>
           </interface-configuration>
        </interfaces>
    </config>
'''

   
reply = m.edit_config(rpc, target='candidate')
print(reply)
reply = m.commit()
print(reply)
# Out:
# ---------------------------------------------------------------------------
# RPCError                                  Traceback (most recent call last)
# <ipython-input-25-b8988501b171> in <module>
#      21
#      22
# ---> 23 reply = m.edit_config(rpc, target='candidate')
#      24 print(reply)
#      25 reply = m.commit()
#
# ~/.local/lib/python3.6/site-packages/ncclient/manager.py in execute(self, cls, *args, **kwds)
#     229                    timeout=self._timeout,
#     230                    raise_mode=self._raise_mode,
# --> 231                    huge_tree=self._huge_tree).request(*args, **kwds)
#     232
#     233     def locked(self, target):
#
# ~/.local/lib/python3.6/site-packages/ncclient/operations/edit.py in request(self, config, format, target, default_operation, test_option, error_option)
#      67             config_text = sub_ele(node, "config-text")
#      68             sub_ele(config_text, "configuration-text").text = config
# ---> 69         return self._request(node)
#      70
#      71
#
# ~/.local/lib/python3.6/site-packages/ncclient/operations/rpc.py in _request(self, op)
#     358                             raise RPCError(to_ele(self._reply._raw), errs=errors)
#     359                         else:
# --> 360                             raise self._reply.error
#     361                 if self._device_handler.transform_reply():
#     362                     return NCElement(self._reply, self._device_handler.transform_reply(), huge_tree=self._huge_tree)
#
# RPCError: Unknown element is specified.

# %%
from ncclient import manager

m = manager.connect(host='198.51.100.1', port=22, username='netman', password='netman', hostkey_verify=False, allow_agent=False, look_for_keys=True, device_params={'name':'iosxr'})

rpc='''
<config xmlns:xc="urn:ietf:params:xml:ns:netconf:base:1.0">
  <interfaces xmlns="http://openconfig.net/yang/interfaces">
   <interface>
    <name>GigabitEthernet0/0/0/0</name>
    <config>
     <name>GigabitEthernet0/0/0/0</name>
     <type xmlns:idx="urn:ietf:params:xml:ns:yang:iana-if-type">idx:ethernetCsmacd</type>
     <enabled>true</enabled>
    </config>
    <ethernet xmlns="http://openconfig.net/yang/interfaces/ethernet">
     <config>
      <auto-negotiate>false</auto-negotiate>
     </config>
    </ethernet>
    <subinterfaces>
     <subinterface>
      <index>0</index>
        <ipv4-packet-filter xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-ip-pfilter-cfg">
         <inbound>
          <acl-name-array>acl_2</acl-name-array>
          <is-common-array>false</is-common-array>
         </inbound>
        </ipv4-packet-filter>
     </subinterface>
    </subinterfaces>
   </interface>
  </interfaces>
</config>
'''

reply = m.edit_config(rpc, target='candidate')
print(reply)
reply = m.commit()
print(reply)
# Out:
# ---------------------------------------------------------------------------
# RPCError                                  Traceback (most recent call last)
# <ipython-input-21-c3ec668caaac> in <module>
#      34 '''
#      35
# ---> 36 reply = m.edit_config(rpc, target='candidate')
#      37 print(reply)
#      38 reply = m.commit()
#
# ~/.local/lib/python3.6/site-packages/ncclient/manager.py in execute(self, cls, *args, **kwds)
#     229                    timeout=self._timeout,
#     230                    raise_mode=self._raise_mode,
# --> 231                    huge_tree=self._huge_tree).request(*args, **kwds)
#     232
#     233     def locked(self, target):
#
# ~/.local/lib/python3.6/site-packages/ncclient/operations/edit.py in request(self, config, format, target, default_operation, test_option, error_option)
#      67             config_text = sub_ele(node, "config-text")
#      68             sub_ele(config_text, "configuration-text").text = config
# ---> 69         return self._request(node)
#      70
#      71
#
# ~/.local/lib/python3.6/site-packages/ncclient/operations/rpc.py in _request(self, op)
#     358                             raise RPCError(to_ele(self._reply._raw), errs=errors)
#     359                         else:
# --> 360                             raise self._reply.error
#     361                 if self._device_handler.transform_reply():
#     362                     return NCElement(self._reply, self._device_handler.transform_reply(), huge_tree=self._huge_tree)
#
# RPCError: Unknown namespace is specified.

# %%
from ncclient import manager

m = manager.connect(host='198.51.100.1', port=22, username='netman', password='netman', hostkey_verify=False, allow_agent=False, look_for_keys=True, device_params={'name':'iosxr'})

rpc='''
<config xmlns:xc="urn:ietf:params:xml:ns:netconf:base:1.0">
  <interfaces xmlns="http://openconfig.net/yang/interfaces">
   <interface>
    <name>GigabitEthernet0/0/0/0</name>
    <config>
     <name>GigabitEthernet0/0/0/0</name>
     <type xmlns:idx="urn:ietf:params:xml:ns:yang:iana-if-type">idx:ethernetCsmacd</type>
     <enabled>true</enabled>
    </config>
    <ethernet xmlns="http://openconfig.net/yang/interfaces/ethernet">
     <config>
      <auto-negotiate>false</auto-negotiate>
     </config>
    </ethernet>
    <subinterfaces>
     <subinterface>
      <index>0</index>
       <ipv4-packet-filter xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-ip-pfilter-cfg">
         <inbound>
          <acl-name-array>acl_1</acl-name-array>
          <is-common-array>false</is-common-array>
         </inbound>
        </ipv4-packet-filter>
     </subinterface>
    </subinterfaces>
   </interface>
  </interfaces>
</config>
'''

reply = m.edit_config(rpc, target='candidate')
print(reply)
reply = m.commit()
print(reply)
# Out:
# ---------------------------------------------------------------------------
# RPCError                                  Traceback (most recent call last)
# <ipython-input-22-783563be9650> in <module>
#      34 '''
#      35
# ---> 36 reply = m.edit_config(rpc, target='candidate')
#      37 print(reply)
#      38 reply = m.commit()
#
# ~/.local/lib/python3.6/site-packages/ncclient/manager.py in execute(self, cls, *args, **kwds)
#     229                    timeout=self._timeout,
#     230                    raise_mode=self._raise_mode,
# --> 231                    huge_tree=self._huge_tree).request(*args, **kwds)
#     232
#     233     def locked(self, target):
#
# ~/.local/lib/python3.6/site-packages/ncclient/operations/edit.py in request(self, config, format, target, default_operation, test_option, error_option)
#      67             config_text = sub_ele(node, "config-text")
#      68             sub_ele(config_text, "configuration-text").text = config
# ---> 69         return self._request(node)
#      70
#      71
#
# ~/.local/lib/python3.6/site-packages/ncclient/operations/rpc.py in _request(self, op)
#     358                             raise RPCError(to_ele(self._reply._raw), errs=errors)
#     359                         else:
# --> 360                             raise self._reply.error
#     361                 if self._device_handler.transform_reply():
#     362                     return NCElement(self._reply, self._device_handler.transform_reply(), huge_tree=self._huge_tree)
#
# RPCError: Unknown namespace is specified.

# %%
from ncclient import manager

m = manager.connect(host='198.51.100.1', port=22, username='netman', password='netman', hostkey_verify=False, allow_agent=False, look_for_keys=True, device_params={'name':'iosxr'})

rpc='''
<config xmlns:xc="urn:ietf:params:xml:ns:netconf:base:1.0">
  <interfaces xmlns="http://openconfig.net/yang/interfaces">
   <interface>
    <name>GigabitEthernet0/0/0/0</name>
    <config>
     <name>GigabitEthernet0/0/0/0</name>
     <type xmlns:idx="urn:ietf:params:xml:ns:yang:iana-if-type">idx:ethernetCsmacd</type>
     <enabled>true</enabled>
    </config>
       <ipv4-packet-filter xmlns="http://cisco.com/ns/yang/Cisco-IOS-XR-ip-pfilter-cfg">
         <inbound>
          <acl-name-array>acl_1</acl-name-array>
          <is-common-array>false</is-common-array>
         </inbound>
        </ipv4-packet-filter>
   </interface>
  </interfaces>
</config>
'''

reply = m.edit_config(rpc, target='candidate')
print(reply)
reply = m.commit()
print(reply)
# Out:
# <?xml version="1.0"?>
# <rpc-reply message-id="urn:uuid:a6faa123-229e-42f2-90a8-63eb80b4759f" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns="urn:ietf:params:xml:ns:netconf:base:1.0">
#  <ok/>
# </rpc-reply>
#
# <?xml version="1.0"?>
# <rpc-reply message-id="urn:uuid:b04820c6-1fa8-4a84-9095-5d6503ad20a7" xmlns:nc="urn:ietf:params:xml:ns:netconf:base:1.0" xmlns="urn:ietf:params:xml:ns:netconf:base:1.0">
#  <ok/>
# </rpc-reply>
